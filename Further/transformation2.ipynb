# %%
import pandas as pd

df_취업률 = pd.read_excel('2021년 학과별 고등교육기관 취업통계.xlsx',
                          sheet_name = '학과별',
                          skiprows=(13),
                          header=0)
df_취업률 = pd.concat([df_취업률.iloc[:,0:8],
                      df_취업률.loc[:,df_취업률.columns.str.endswith('계')],
                      df_취업률.loc[:,'입대자']],axis=1)
df_취업률_500 = df_취업률.loc[(df_취업률['졸업자_계'] < 500)]
df_취업률_500 = df_취업률_500.iloc[range(0,len(df_취업률_500.index),4)]
df_취업률_500 = df_취업률_500.rename(columns={'졸업자_계':'졸업자수',
                                        '취업률_계':'취업률','취업자_합계_계':'취업자수'})
df_취업률_500
# Out:
#            조사기준일    학제    과정구분    대계열    중계열    소계열          학과코드         학과명  \
# 0     2021.12.31  전문대학  전문대학과정   인문계열  언어ㆍ문학    일본어  C01010100002      관광일본어과
# 1     2021.12.31  전문대학  전문대학과정   인문계열  언어ㆍ문학    일본어  C01010100003     관광일본어전공
# 2     2021.12.31  전문대학  전문대학과정   인문계열  언어ㆍ문학    일본어  C01010100005       관광일어과
# 3     2021.12.31  전문대학  전문대학과정   인문계열  언어ㆍ문학    일본어  C01010100011      실무일본어과
# 4     2021.12.31  전문대학  전문대학과정   인문계열  언어ㆍ문학    일본어  C01010100013        일본어과
# ...          ...   ...     ...    ...    ...    ...           ...         ...
# 9401  2021.12.31  기능대학  전문대학과정  예체능계열    디자인  기타디자인  C07010400310     주얼리디자인과
# 9402  2021.12.31  기능대학  전문대학과정  예체능계열    디자인  기타디자인  C07010400403      융합디자인과
# 9403  2021.12.31  기능대학  전문대학과정  예체능계열    디자인  기타디자인  C07010410015  스마트 제품디자인과
# 9404  2021.12.31  기능대학  전문대학과정  예체능계열   응용예술  영상·예술  C07020300014      영상그래픽과
# 9405  2021.12.31  기능대학  전문대학과정  예체능계열  무용ㆍ체육     체육  C07030200177       산업잠수과
#
#       졸업자_계  취업률_계  ...  1차 유지취업자_계  1차 유지취업률_계  2차 유지취업자_계  2차 유지취업률_계  \
# 0        79   29.6  ...          10        76.9           8        61.5
# 1        26   61.1  ...           7        87.5           7        87.5
# 2       107   50.0  ...          34        81.0          32        76.2
# 3       109   52.3  ...          29        72.5          27        67.5
# 4        63   46.2  ...          14        70.0          13        65.0
# ...     ...    ...  ...         ...         ...         ...         ...
# 9401     39   81.1  ...          15        75.0          13        65.0
# 9402     33   87.1  ...          15        68.2          15        68.2
# 9403     21   83.3  ...           9        90.0           8        80.0
# 9404     14   84.6  ...           7       100.0           7       100.0
# 9405     26   54.5  ...           8        80.0           8        80.0
#
#       3차 유지취업자_계  3차 유지취업률_계  4차 유지취업자_계  4차 유지취업률_계  입학당시 기취업자_계  입대자
# 0              7        53.8           5        38.5            0   14
# 1              7        87.5           7        87.5            1    0
# 2             27        64.3          25        59.5            4    3
# 3             24        60.0          21        52.5            4    0
# 4              8        40.0           8        40.0            4    4
# ...          ...         ...         ...         ...          ...  ...
# 9401          10        50.0          10        50.0            1    0
# 9402          15        68.2          15        68.2            0    1
# 9403           6        60.0           5        50.0            0    3
# 9404           6        85.7           6        85.7            0    1
# 9405           8        80.0           8        80.0            0    3
#
# [9406 rows x 35 columns]

# %%
df_취업률_500 = df_취업률.loc[(df_취업률['졸업자_계'] < 500)]
df_취업률_500 = df_취업률_500.iloc[range(0,len(df_취업률_500.index),4)]
df_취업률_500 = df_취업률_500.rename(columns={'졸업자_계':'졸업자수',
                                        '취업률_계':'취업률','취업자_합계_계':'취업자수'})
df_취업률_500
# Out:
#            조사기준일    학제    과정구분    대계열       중계열    소계열          학과코드  \
# 0     2021.12.31  전문대학  전문대학과정   인문계열     언어ㆍ문학    일본어  C01010100002
# 4     2021.12.31  전문대학  전문대학과정   인문계열     언어ㆍ문학    일본어  C01010100013
# 8     2021.12.31  전문대학  전문대학과정   인문계열     언어ㆍ문학    일본어  C01010100049
# 12    2021.12.31  전문대학  전문대학과정   인문계열     언어ㆍ문학    중국어  C01010200003
# 16    2021.12.31  전문대학  전문대학과정   인문계열     언어ㆍ문학    중국어  C01010200011
# ...          ...   ...     ...    ...       ...    ...           ...
# 9388  2021.12.31  기능대학  전문대학과정   자연계열  생물ㆍ화학ㆍ환경     생물  C05020100066
# 9392  2021.12.31  기능대학  전문대학과정   의약계열     치료ㆍ보건   의료장비  C06020300002
# 9396  2021.12.31  기능대학  전문대학과정  예체능계열       디자인  패션디자인  C07010300011
# 9400  2021.12.31  기능대학  전문대학과정  예체능계열       디자인  기타디자인  C07010400214
# 9404  2021.12.31  기능대학  전문대학과정  예체능계열      응용예술  영상·예술  C07020300014
#
#                    학과명  졸업자수   취업률  ...  1차 유지취업자_계  1차 유지취업률_계  2차 유지취업자_계  \
# 0               관광일본어과    79  29.6  ...          10        76.9           8
# 4                 일본어과    63  46.2  ...          14        70.0          13
# 8     항공호텔관광학부 일본어통역전공    40  37.5  ...           5        62.5           5
# 12              관광중국어과   225  51.9  ...          68        84.0          62
# 16                중국어과     5  60.0  ...           3       100.0           2
# ...                ...   ...   ...  ...         ...         ...         ...
# 9388          바이오품질관리과    28  89.3  ...          25       100.0          25
# 9392             의료공학과     1   0.0  ...           0         0.0           0
# 9396            패션디자인과    21  87.5  ...           8        80.0           6
# 9400            금형디자인과   326  80.3  ...         209        89.7         197
# 9404            영상그래픽과    14  84.6  ...           7       100.0           7
#
#       2차 유지취업률_계  3차 유지취업자_계  3차 유지취업률_계  4차 유지취업자_계  4차 유지취업률_계  입학당시 기취업자_계  \
# 0           61.5           7        53.8           5        38.5            0
# 4           65.0           8        40.0           8        40.0            4
# 8           62.5           5        62.5           5        62.5            0
# 12          76.5          53        65.4          52        64.2            6
# 16          66.7           2        66.7           2        66.7            0
# ...          ...         ...         ...         ...         ...          ...
# 9388       100.0          23        92.0          23        92.0            0
# 9392         0.0           0         0.0           0         0.0            0
# 9396        60.0           5        50.0           4        40.0            0
# 9400        84.5         184        79.0         178        76.4           15
# 9404       100.0           6        85.7           6        85.7            0
#
#       입대자
# 0      14
# 4       4
# 8       2
# 12      9
# 16      0
# ...   ...
# 9388    0
# 9392    0
# 9396    2
# 9400   22
# 9404    1
#
# [2313 rows x 35 columns]
